# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
LowStudy = []
ModerateStudy = []
HighStudy = []

# %%
for days in time_data:
    if days[0] < 3:
        LowStudy.append(days)
    if (days[0] >= 3) & (days[0] < 5):
        ModerateStudy.append(days)
    else:
        HighStudy.append(days)

# %%
print(LowStudy)
print(ModerateStudy)
print(HighStudy)
# Out:
# [(2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (2.0, 3.5, 8.5), (2.5, 4.0, 8.0), (2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (2.0, 3.5, 8.5), (2.5, 4.0, 8.0)]
# [(3.5, 2.0, 7.0), (4.0, 2.0, 6.0), (3.0, 2.5, 7.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5), (4.0, 2.5, 7.0), (3.5, 2.5, 7.0), (3.5, 2.0, 7.0), (4.0, 2.0, 6.0), (3.0, 2.5, 7.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5), (4.0, 2.5, 7.0), (3.5, 2.5, 7.0)]
# [(5.0, 1.5, 6.5), (2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0), (5.0, 2.0, 6.5), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0), (5.0, 2.0, 6.5)]

# %%
LowStudy_no = len(LowStudy)
ModerateStudy_no = len(ModerateStudy)
HighStudy_no = len(HighStudy)

# %%
print("Days with low level studies : ", LowStudy_no)
print("Days with moderate level studies : ", ModerateStudy_no)
print("Days with high level studies : ", HighStudy_no)
# Out:
# Days with low level studies :  8
# Days with moderate level studies :  14
# Days with high level studies :  16

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
minutes_data = []
for days in time_data:
    minutes = [0,0,0]
    minutes[0] = days[0] * 60
    minutes[1] = days[1] * 60
    minutes[2] = days[2] * 60
    minutes = (minutes[0], minutes[1], minutes[2])
    minutes_data.append(minutes)

# %%
print(minutes_data)
# Out:
# [(210.0, 120.0, 420.0), (300.0, 90.0, 390.0), (150.0, 180.0, 480.0), (240.0, 120.0, 360.0), (90.0, 270.0, 540.0), (180.0, 150.0, 450.0), (330.0, 60.0, 360.0), (120.0, 210.0, 510.0), (270.0, 120.0, 420.0), (180.0, 180.0, 450.0), (360.0, 90.0, 360.0), (150.0, 240.0, 480.0), (240.0, 150.0, 420.0), (300.0, 120.0, 390.0), (210.0, 150.0, 420.0)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
StudyHours = []
EntertainmentHours = []
SleepHours = []

# %%
for days in time_data:
    StudyHours.append(days[0])
    EntertainmentHours.append(days[1])
    SleepHours.append(days[2])
print(StudyHours)
print(EntertainmentHours)
print(SleepHours)
# Out:
# [3.5, 5.0, 2.5, 4.0, 1.5, 3.0, 5.5, 2.0, 4.5, 3.0, 6.0, 2.5, 4.0, 5.0, 3.5, 3.5, 5.0, 2.5, 4.0, 1.5, 3.0, 5.5, 2.0, 4.5, 3.0, 6.0, 2.5, 4.0, 5.0, 3.5]
# [2.0, 1.5, 3.0, 2.0, 4.5, 2.5, 1.0, 3.5, 2.0, 3.0, 1.5, 4.0, 2.5, 2.0, 2.5, 2.0, 1.5, 3.0, 2.0, 4.5, 2.5, 1.0, 3.5, 2.0, 3.0, 1.5, 4.0, 2.5, 2.0, 2.5]
# [7.0, 6.5, 8.0, 6.0, 9.0, 7.5, 6.0, 8.5, 7.0, 7.5, 6.0, 8.0, 7.0, 6.5, 7.0, 7.0, 6.5, 8.0, 6.0, 9.0, 7.5, 6.0, 8.5, 7.0, 7.5, 6.0, 8.0, 7.0, 6.5, 7.0]

# %%
totalstudyhours = 0
for studyhours in StudyHours:
    totalstudyhours += studyhours
avgstudyhours = totalstudyhours / len(StudyHours)
print(avgstudyhours)
# Out:
# 3.7

# %%
totalenterhours = 0
for enterhours in EntertainmentHours:
    totalenterhours += enterhours
avgenterhours = totalenterhours / len(EntertainmentHours)
print(avgenterhours)
# Out:
# 2.5

# %%
totalsleephours = 0
for sleephours in SleepHours:
    totalsleephours += sleephours
avgsleephours = totalsleephours / len(SleepHours)
print(avgsleephours)
# Out:
# 7.166666666666667

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
plt.scatter(StudyHours,SleepHours)
plt.xlabel("Study hours")
plt.ylabel("Sleep hours")
plt.title("study vs sleep")
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def sum_nested_list(nested_list):
    """
    Args:
    nested_list (list): A list that may contain integers or other lists of integers.
    Returns:
    int: The total sum of all integers in the nested list, including those in sublists
    .
    Example:
    >>> sum_nested_list([1, [2, [3, 4], 5], 6, [7, 8]])
    36
    >>> sum_nested_list([1, [2, 3], [4, [5]]])
    15
    """
    total = 0
    for element in nested_list:
        if isinstance(element, list):
            total += sum_nested_list(element)
        else:
            total += element
    return total

# %%
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
print(sum_nested_list(nested_list))
# Out:
# 36

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def generate_permutations(s):
    """
    Args:
        s (str): The input string for which permutations are to be generated.

    Returns:
        list: A list of all possible permutations of the input string. Each
        permutation is represented as a string.

    Example:
        >>> generate_permutations("abc")
        ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
    """
    if len(s) == 1:
        return [s]

    permutations = []

    for i in range(len(s)):
        char = s[i]                
        remaining = s[:i] + s[i+1:]

        for perm in generate_permutations(remaining):
            permutations.append(char + perm)

    return permutations

# %%
per = generate_permutations("pankaj")
print(per)
# Out:
# ['pankaj', 'pankja', 'panakj', 'panajk', 'panjka', 'panjak', 'paknaj', 'paknja', 'pakanj', 'pakajn', 'pakjna', 'pakjan', 'paankj', 'paanjk', 'paaknj', 'paakjn', 'paajnk', 'paajkn', 'pajnka', 'pajnak', 'pajkna', 'pajkan', 'pajank', 'pajakn', 'pnakaj', 'pnakja', 'pnaakj', 'pnaajk', 'pnajka', 'pnajak', 'pnkaaj', 'pnkaja', 'pnkaaj', 'pnkaja', 'pnkjaa', 'pnkjaa', 'pnaakj', 'pnaajk', 'pnakaj', 'pnakja', 'pnajak', 'pnajka', 'pnjaka', 'pnjaak', 'pnjkaa', 'pnjkaa', 'pnjaak', 'pnjaka', 'pkanaj', 'pkanja', 'pkaanj', 'pkaajn', 'pkajna', 'pkajan', 'pknaaj', 'pknaja', 'pknaaj', 'pknaja', 'pknjaa', 'pknjaa', 'pkaanj', 'pkaajn', 'pkanaj', 'pkanja', 'pkajan', 'pkajna', 'pkjana', 'pkjaan', 'pkjnaa', 'pkjnaa', 'pkjaan', 'pkjana', 'paankj', 'paanjk', 'paaknj', 'paakjn', 'paajnk', 'paajkn', 'panakj', 'panajk', 'pankaj', 'pankja', 'panjak', 'panjka', 'pakanj', 'pakajn', 'paknaj', 'paknja', 'pakjan', 'pakjna', 'pajank', 'pajakn', 'pajnak', 'pajnka', 'pajkan', 'pajkna', 'pjanka', 'pjanak', 'pjakna', 'pjakan
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def calculate_directory_size(directory):
    """
    Args:
        directory (dict): The directory structure where values are either integers
                          (file sizes) or dictionaries (subdirectories).

    Returns:
        int: The total size (in KB) of all files contained in the directory and all
             nested subdirectories.

    Example:
        >>> calculate_directory_size({
        ...     "file1.txt": 200,
        ...     "subdir": {"file2.txt": 300}
        ... })
        500
    """
    total = 0

    for key, value in directory.items():
        if isinstance(value, dict):
            total += calculate_directory_size(value)
        else:
            total += value

    return total

# %%
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {"file3.txt": 400, "file4.txt": 100},
    "subdir2": {"subsubdir1": {"file5.txt": 250}, "file6.txt": 150},
}

print(calculate_directory_size(directory_structure))
# Out:
# 1400

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def min_coins(coins, amount):
    """
    Parameters:
    coins (list of int): A list of coin denominations available for making change. Each
    coin denomination is a positive integer.
    amount (int): The target amount for which we need to find the minimum number of coins
    . It must be a non-negative integer.
    Returns:
    int: The minimum number of coins required to make the given amount.
    If it is not possible to make the amount with the given coins, returns -1.
    Example:
    3>>> min_coins([1, 2, 5], 11)
    >>> min_coins([2], 3)
    -1
    """
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0
    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)
    return dp[amount] if dp[amount] != float('inf') else -1

# %%
print(min_coins([2,3,5,7,9],1001))
# Out:
# 112

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def longest_common_subsequence(s1, s2):
    """
    Args:
        s1 (str): The first string.
        s2 (str): The second string.

    Returns:
        int: The length of the longest common subsequence.

    Example:
        >>> longest_common_subsequence("abcde", "ace")
        3
    """

    m, n = len(s1), len(s2)

    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = 1 + dp[i - 1][j - 1]
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

# %%
print(longest_common_subsequence("Hello Brother","phone"))
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [0] * (capacity + 1)

    for i in range(n):
        w = weights[i]
        v = values[i]
        for c in range(capacity, w - 1, -1):
            dp[c] = max(dp[c], dp[c - w] + v)

    return dp[capacity]

# %%
print(knapsack([1,3,4,5],[1,4,5,7],7))
# Out:
# 9
